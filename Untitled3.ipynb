# %% [markdown]
# <a href="https://colab.research.google.com/github/ranam7amad/CODSOFT/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("fraudTrain.csv")
train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street            city state    zip  \
# 0    Banks      F                561 Perry Cove  Moravian Falls    NC  28654
# ...

# %%
test = pd.read_csv("fraudTest.csv")
test.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street        city state      zip  \
# 0   Elliott      M            351 Darlene Green    Columbia    SC  29209.0
# ...

# %%
train['split'] = 'train'
test['split']='test'
df = pd.concat([train,test],axis=0).reset_index(drop=True)
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street            city state  \
# 0    Banks      F                561 Perry Cove  Moravian Falls    NC
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 1
# category                 1
# amt                      1
# first                    1
# last                     1
# gender                   1
# street                   1
# city                     1
# state                    1
# zip                      1
# lat                      1
# long                     1
# city_pop                 1
# job                      1
# dob                      1
# trans_num                1
# unix_time                2
# merch_lat                2
# merch_long               2
# is_fraud                 2
# split                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['Unnamed: 0','street','state','first','last','trans_num','unix_time'],inplace=True)

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt gender            city      zip      lat      long  \
# 0       misc_net    4.97      F  Moravian Falls  28654.0  36.0788  -81.1781
# 1    grocery_pos  107.23      F          Orient  99160.0  48.8878 -118.2105
# 2  entertainment  220.11      M      Malad City  83252.0  42.1808 -112.2620
# 3  gas_transport   45.00      M         Boulder  59632.0  46.2306 -112.1138
# 4       misc_pos   41.96      M        Doe Hill  24433.0  38.4207  -79.4629
#
# ...

# %%
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])

# %%
df['hour'] = df['trans_date_trans_time'].dt.hour
df['day'] = df['trans_date_trans_time'].dt.day_name()
df['month'] = df['trans_date_trans_time'].dt.month
df.drop(columns=['lat','long','merch_lat','merch_long'],inplace=True)

# %%
df.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt gender            city      zip  city_pop  \
# 0       misc_net    4.97      F  Moravian Falls  28654.0    3495.0
# 1    grocery_pos  107.23      F          Orient  99160.0     149.0
# 2  entertainment  220.11      M      Malad City  83252.0    4154.0
# 3  gas_transport   45.00      M         Boulder  59632.0    1939.0
# 4       misc_pos   41.96      M        Doe Hill  24433.0      99.0
#
#                                  job         dob  is_fraud  split  hour  \
# ...

# %%
def data_pre(X):
    del_col=['merchant','first','last','street','zip','unix_time','Unnamed: 0','trans_num','cc_num']
    X.drop(columns=del_col,inplace=True)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
def evl_model(xtrain,ytrain,xtest,ytest):
    sns.set(rc={'figure.figsize':(18,6)})
    i=0
    for name,model in evl_models.items():
        fig,axs=plt.subplots(1,2)
        print('Model : '+name)
        print('_'*30)
        start=time()
        model.fit(xtrain,ytrain)
        y_pred = model.predict(xtest)
        end=time()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test = train_test_split(x_train, test_size = 0.20, random_state = 0)

# %%
logistic_regression=LogisticRegression()
logistic_regression.fit(x_train,x_test)
y_pred_logistic = logistic_regression.predict(x_test)
accuracy_logistic = accuracy_score(x_test, y_pred_logistic)
accuracy_logistic
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-407-024f56b18e13> in <cell line: 2>()
#       1 logistic_regression=LogisticRegression()
# ----> 2 logistic_regression.fit(x_train,x_test)
#       3 y_pred_logistic = logistic_regression.predict(x_test)
#       4 accuracy_logistic = accuracy_score(x_test, y_pred_logistic)
#       5 accuracy_logistic
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# ...

# %%
DecisionTree=DecisionTreeClassifier()
DecisionTree.fit(x_train,x_test)
y_pred_dt = DecisionTree.predict(x_test)
accuracy_dt = accuracy_score(x_train, x_test)
accuracy_dt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-408-1ecd0b6f05ae> in <cell line: 2>()
#       1 DecisionTree=DecisionTreeClassifier()
# ----> 2 DecisionTree.fit(x_train,x_test)
#       3 y_pred_dt = DecisionTree.predict(x_test)
#       4 accuracy_dt = accuracy_score(x_train, x_test)
#       5 accuracy_dt
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     887         """
#     888
# --> 889         super().fit(
#     890             X,
#     891             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     184             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186             X, y = self._validate_data(
# ...

# %%
print("\nClassification Report for Logistic Regression:\n", classification_report(x_test, y_pred_logistic))
print("\nClassification Report for Decision Tree:\n", classification_report(x_test, y_pred_logistic))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-412-78cfe572c66d> in <cell line: 1>()
# ----> 1 print("\nClassification Report for Logistic Regression:\n", classification_report(x_test, y_pred_logistic))
#       2 print("\nClassification Report for Decision Tree:\n", classification_report(x_test, y_pred_logistic))
#
# NameError: name 'y_pred_logistic' is not defined
